# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_partidos = pd.read_csv("./data/partidos_cebollitas.csv")

# %%
df_partidos.describe()
# Out:
#        goles_local  goles_visitante  posesion_local (%)  \
# count    100.00000       100.000000          100.000000
# mean       2.63000         2.540000           50.250000
# std        1.58691         1.788967            6.035878
# min        0.00000         0.000000           40.000000
# 25%        1.00000         1.000000           45.000000
# 50%        3.00000         3.000000           51.000000
# 75%        4.00000         4.000000           55.250000
# max        5.00000         5.000000           60.000000
#
#        posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante
# count              100.000000        100.000000            100.000000
# mean                49.750000          7.580000              7.870000
# std                  6.035878          2.899599              2.966667
# min                 40.000000          3.000000              3.000000
# 25%                 44.750000          5.000000              5.000000
# ...

# %%
goles_local_cebollitas = df_partidos[df_partidos["equipo_local"] == "Cebollitas FC"]["goles_local"].mean()
goles_visitante_cebollitas = df_partidos[df_partidos["equipo_visitante"] == "Cebollitas FC"]["goles_visitante"].mean()

goles_local_cebollitas = df_partidos[df_partidos["equipo_local"] == "Cebollitas FC"]["goles_local"].sum()
# Out:
# Cebollitas FC en promedio ha marcado 2.230769230769231 goles como local y 2.611111111111111 goles como visitante

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4))

sns.histplot(df_partidos[df_partidos["equipo_local"] == "Cebollitas FC"]["goles_local"], kde=True, ax=ax[0], bins=10)
ax[0].set_title("Distribución de goles marcados por el equipo local Cebollitas FC")

sns.histplot(df_partidos[df_partidos["equipo_visitante"] == "Cebollitas FC"]["goles_visitante"], kde=True, ax=ax[1], bins=10, color="red")
ax[1].set_title("Distribución de goles marcados por el equipo visitante Cebollitas FC")

plt.show()

# %%
sns.boxplot(x="equipo_local", y="goles_local", data=df_partidos)
# Out:
# <Axes: xlabel='equipo_local', ylabel='goles_local'>

# %%
sns.boxplot(x="equipo_visitante", y="goles_visitante", data=df_partidos)
# Out:
# <Axes: xlabel='equipo_visitante', ylabel='goles_visitante'>

# %%
sns.scatterplot(x="posesion_local (%)", y="goles_local", data=df_partidos)
plt.title("Relación entre la posesion local y los goles marcados por el equipo local")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_partidos[["goles_local", "goles_visitante", "posesion_local (%)", "posesion_visitante (%)", "tiros_arco_local", "tiros_arco_visitante"]].corr(), annot=True, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()
